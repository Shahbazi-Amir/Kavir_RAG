# %%
# !git clone https://github.com/Shahbazi-Amir/Kavir_RAG.git
# %cd Kavir_RAG
# !ls
# Out:
# fatal: destination path 'Kavir_RAG' already exists and is not an empty directory.
# /content/Kavir_RAG
# data	    docs	   llama.cpp		 requirements.base.txt	src
# Dockerfile  entrypoint.sh  requirements.app.txt  run_docker.sh

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
# !mkdir -p data/raw

# %%
# !ls data
# Out:
# ls: cannot access 'data': No such file or directory

# %%
# !pip install -r requirements.base.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.4/190.4 MB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 23.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 127.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 109.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 8.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ...

# %%
# !pip install -r requirements.app.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 19.5 MB/s eta 0:00:00
# ...

# %%
# !pip install -U \
  "transformers==4.38.2" \
  "sentence-transformers==2.6.1"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.7/130.7 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 130.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.3/163.3 kB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 117.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.1
#     Uninstalling tokenizers-0.22.1:
#       Successfully uninstalled tokenizers-0.22.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.3
#     Uninstalling transformers-4.57.3:
#       Successfully uninstalled transformers-4.57.3
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 3.0.1
#     Uninstalling sentence-transformers-3.0.1:
#       Successfully uninstalled sentence-transformers-3.0.1
# ...

# %%
# !pip uninstall -y torch torchvision torchaudio
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Found existing installation: torch 2.3.1+cpu
# Uninstalling torch-2.3.1+cpu:
#   Successfully uninstalled torch-2.3.1+cpu
# Found existing installation: torchvision 0.24.0+cu126
# Uninstalling torchvision-0.24.0+cu126:
#   Successfully uninstalled torchvision-0.24.0+cu126
# Found existing installation: torchaudio 2.9.0+cu126
# Uninstalling torchaudio-2.9.0+cu126:
#   Successfully uninstalled torchaudio-2.9.0+cu126
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.4/780.4 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 128.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 107.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 115.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 60.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 143.2 MB/s eta 0:00:00
# ...

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# CUDA version: 12.1
# GPU: Tesla T4

# %%
# !rm -rf data/chunks_test
# !time python -m src.ingest_stream_cli \
  --input data/raw/persian_2m.txt \
  --out data/chunks_test
# Out:
# /usr/bin/python3: Error while finding module specification for 'src.ingest_stream_cli' (ModuleNotFoundError: No module named 'src')
#
# real	0m0.059s
# user	0m0.042s
# sys	0m0.014s

# %%
from sentence_transformers import SentenceTransformer
import torch

print("CUDA:", torch.cuda.is_available())
model = SentenceTransformer(
    "intfloat/multilingual-e5-small",
    device="cuda"
)
print("MODEL LOADED")
# Out:
# CUDA: True
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ...

# %%
# !time python -m src.embeddings \
  --input data/chunks_test \
  --out data/index_test \
  --batch 16
# Out:
# /usr/bin/python3: Error while finding module specification for 'src.embeddings' (ModuleNotFoundError: No module named 'src')
#
# real	0m0.060s
# user	0m0.046s
# sys	0m0.014s

# %%
# %cd /content/Kavir_RAG
# !export PYTHONPATH=$PYTHONPATH:/content/Kavir_RAG
# !time python -m src.embeddings \
  --input data/chunks_test \
  --out data/index_test \
  --batch 16
# Out:
# /content/Kavir_RAG
# 🔹 Loading embedding model on [CUDA]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 🔹 Reading chunks from data/chunks_test
#    → 2154 chunks
# 🔹 Computing embeddings
#    → Embedding shape: (2154, 384)
# 🔹 Writing vectors → data/index_test/vectors.npy
# 🔹 Writing metadata → data/index_test/meta.jsonl
# ✅ Index build finished (NumPy backend)
#
# real	0m33.422s
# user	0m27.303s
# sys	0m1.456s

# %%
# !rm -rf data/chunks_5m
# !time python -m src.ingest_stream_cli \
  --input data/raw/persian_5m.txt \
  --out data/chunks_5m
# Out:
# Validated 6453 chunks successfully.
#
# real	0m0.266s
# user	0m0.220s
# sys	0m0.045s

# %%
# !time python -m src.embeddings \
  --input data/chunks_5m \
  --out data/index_5m \
  --batch 16
# Out:
# 🔹 Loading embedding model on [CUDA]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 🔹 Reading chunks from data/chunks_5m
#    → 6453 chunks
# 🔹 Computing embeddings
#    → Embedding shape: (6453, 384)
# 🔹 Writing vectors → data/index_5m/vectors.npy
# 🔹 Writing metadata → data/index_5m/meta.jsonl
# ✅ Index build finished (NumPy backend)
#
# real	1m49.154s
# user	1m47.958s
# sys	0m1.661s

# %%
# !rm -rf data/chunks_100m/*
# !time python -m src.ingest_stream_cli \
  --input data/raw/persian_100m.txt \
  --out data/chunks_100m
# Out:
# Validated 4264 chunks successfully.
#
# real	0m0.218s
# user	0m0.181s
# sys	0m0.035s

# %%
import torch
print("CUDA:", torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# CUDA: True
# Tesla T4

# %%
# !time python -m src.embeddings \
  --input data/chunks_100m \
  --out data/index_100m \
  --batch 32
# Out:
# 🔹 Loading embedding model on [CUDA]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 🔹 Reading chunks from data/chunks_100m
#    → 4264 chunks
# 🔹 Computing embeddings
#    → Embedding shape: (4264, 384)
# 🔹 Writing vectors → data/index_100m/vectors.npy
# 🔹 Writing metadata → data/index_100m/meta.jsonl
# ✅ Index build finished (NumPy backend)
#
# real	0m49.563s
# user	0m47.011s
# sys	0m1.409s

# %%
# %cd /content/Kavir_RAG
# !mkdir -p data/raw
# !mkdir -p data/chunks_500m
# !mkdir -p data/index_500m
# Out:
# /content/Kavir_RAG

# %%
# !rm -rf data/chunks_500m/*
# !time python -m src.ingest_stream_cli \
  --input data/raw/persian_500m.txt \
  --out data/chunks_500m
# Out:
# Validated 1031 chunks successfully.
#
# real	0m0.109s
# user	0m0.090s
# sys	0m0.018s

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
# !time python -m src.embeddings \
  --input data/chunks_500m \
  --out data/index_500m \
  --batch 32
# Out:
# 🔹 Loading embedding model on [CUDA]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 🔹 Reading chunks from data/chunks_500m
#    → 1031 chunks
# 🔹 Computing embeddings
#    → Embedding shape: (1031, 384)
# 🔹 Writing vectors → data/index_500m/vectors.npy
# 🔹 Writing metadata → data/index_500m/meta.jsonl
# ✅ Index build finished (NumPy backend)
#
# real	0m19.153s
# user	0m15.753s
# sys	0m1.297s

# %%
# %cd /content/Kavir_RAG
# !mkdir -p data/raw
# !mkdir -p data/chunks_100m
# !mkdir -p data/index_100m
# Out:
# /content/Kavir_RAG

# %%
# !rm -rf data/chunks_100m/*
# !time python -m src.ingest_stream_cli \
  --input data/raw/persian_100m.txt \
  --out data/chunks_100m
# Out:
# Validated 66141 chunks successfully.
#
# real	0m2.115s
# user	0m1.831s
# sys	0m0.278s

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
# !time python -m src.embeddings \
  --input data/chunks_100m \
  --out data/index_100m \
  --batch 32

# %% [markdown]
# تست چانک پایین در ۵۰۰ مگ هم گرفته شد
# اما چانک بالا در صد مگ که میشود حدودا ۶۶ هزار تا چانک نشد که انجام شود بخاطر قطعی زیاد ران تایم

# %% [markdown]
# https://colab.research.google.com/drive/1eHgEZGZ-mIHDzeC102aMQJeYzSkePrlG?authuser=1#scrollTo=8xo1qvF67yoU
